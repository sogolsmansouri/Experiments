# %%
import matplotlib.pyplot as plt
import numpy as np

# Adjusting the bar chart with the updated font size for all labels and ticks, and removing the title

# Setting up the figure size
plt.figure(figsize=(12, 10))

# Creating the bar positions again
bar_positions = np.arange(len(categories))

# Plotting gas costs with log scale
plt.bar(bar_positions - bar_width/2, gas_costs, width=bar_width, label='Gas Cost', color='blue')

# Plotting times with log scale
plt.bar(bar_positions + bar_width/2, times_adjusted, width=bar_width, label='Time (ms)', color='red')

# Adding labels without a title
plt.xlabel('Transaction Type', fontsize=24)
plt.ylabel('Value (log scale)', fontsize=24)
plt.xticks(bar_positions, categories, fontsize=18)
plt.yticks(fontsize=18)
plt.legend(fontsize=18)

# Setting the y-axis to logarithmic scale
plt.yscale('log')

# Adding the text labels on the bars
for idx, (g, t) in enumerate(zip(gas_costs, times_adjusted)):
    if g != 0:
        plt.text(idx - bar_width/2, g, gas_labels[idx], ha='center', va='bottom', fontsize=18)
    if t != 0:
        plt.text(idx + bar_width/2, t, time_labels[idx], ha='center', va='bottom', fontsize=18)

# Setting the minimum value on y-axis to 1 to avoid negative infinity values on log scale
plt.ylim(bottom=1)

# Displaying the plot
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 13
#       7 plt.figure(figsize=(12, 10))
#       9 # Creating the bar positions again
#      10 #bar_positions = np.arange(len(categories))
#      11
#      12 # Plotting gas costs with log scale
# ---> 13 plt.bar(bar_positions - bar_width/2, gas_costs, width=bar_width, label='Gas Cost', color='blue')
#      15 # Plotting times with log scale
#      16 plt.bar(bar_positions + bar_width/2, times_adjusted, width=bar_width, label='Time (ms)', color='red')
#
# NameError: name 'bar_positions' is not defined

# %%
import matplotlib.pyplot as plt
import numpy as np
# Re-creating the bar chart with a logarithmic scale and omitting the red bar for the EOA to EOA transaction as per the script provided

# Defining the necessary variables as they appear to be missing in the provided script
categories = ['ETH: Native', 'ETH: Smart Contract', 'Declarative SmartchainDB']
gas_costs = [21000, 31094, 0]  # Replacing None with 0 for SCDB as it's not provided
times_adjusted = [0, 195, 108]  # Setting the time for EOA to EOA to 0, which won't show on a log scale
gas_labels = ['21,000', '31,094', 'N/A']  # N/A for SCDB gas
time_labels = ['N/A', '195 ms', '108 ms']  # N/A for EOA to EOA time
bar_width = 0.35  # Bar width for both gas and time bars

# Setting up the figure size
plt.figure(figsize=(10, 8))

# Creating the bar positions again
bar_positions = np.arange(len(categories))

# Plotting gas costs with log scale
plt.bar(bar_positions - bar_width/2, gas_costs, width=bar_width, label='Gas Cost', color='blue')

# Plotting times with log scale, omitting the time for EOA to EOA by setting it to zero
plt.bar(bar_positions + bar_width/2, times_adjusted, width=bar_width, label='Time (ms)', color='red')

# Adding labels and title with log scale note
plt.xlabel('Transaction Type', fontsize=20)
plt.ylabel('Value (log scale)', fontsize=20)
plt.xticks(bar_positions, categories, fontsize=16)
plt.yticks(fontsize=16)
plt.legend(fontsize=16)


# Setting the y-axis to logarithmic scale
plt.yscale('log')

# Adding the text labels on the bars
for idx, (g, t) in enumerate(zip(gas_costs, times_adjusted)):
    if g != 0:
        plt.text(idx - bar_width/2, g, gas_labels[idx], ha='center', va='bottom', fontsize=16)
    if t != 0:
        plt.text(idx + bar_width/2, t, time_labels[idx], ha='center', va='bottom', fontsize=15)

# Setting the minimum value on y-axis to 1 to avoid negative infinity values on log scale
plt.ylim(bottom=1)
plt.rcParams['axes.spines.top'] = False
plt.rcParams['axes.spines.right'] = False
plt.gcf().set_facecolor('none')
# Displaying the plot
plt.tight_layout()
plt.plot()
# Out:
# []

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the necessary variables
categories = ['ETH: Native', 'ETH: Smart Contract', 'Declarative \n SmartchainDB']
gas_costs = [21000, 31094, 0]  # Assuming 0 for SCDB as it's not provided
times_adjusted = [0, 195, 108]
gas_labels = ['21,000', '31,094', 'N/A']
time_labels = ['N/A', '195 ms', '108 ms']
bar_width = 0.35

# Set up the figure size
plt.figure(figsize=(8, 6))

# Create the bar positions
bar_positions = np.arange(len(categories))

# Plot gas costs with log scale
plt.bar(bar_positions - bar_width/2, gas_costs, width=bar_width, label='Gas Cost', color='blue')
# Plot times with log scale, omitting the time for EOA to EOA by setting it to zero
plt.bar(bar_positions + bar_width/2, times_adjusted, width=bar_width, label='Time (ms)', color='red')

# Add labels and title with log scale note
plt.xlabel('Transaction Type', fontsize=20)
plt.ylabel('Value (log scale)', fontsize=20)
plt.xticks(bar_positions, categories, fontsize=16)
plt.yticks(fontsize=16)
plt.legend(fontsize=16)

# Set the y-axis to logarithmic scale
plt.yscale('log')

# Adjust the y-axis limits to proportionally compress the view
min_value = np.min([x for x in gas_costs + times_adjusted if x > 0])  # smallest non-zero value
max_value = np.max(gas_costs + times_adjusted)  # maximum value
plt.ylim(bottom=min_value / 10, top=max_value * 10)

# Add text labels on the bars
for idx, (g, t) in enumerate(zip(gas_costs, times_adjusted)):
    if g != 0:
        plt.text(idx - bar_width/2, g, gas_labels[idx], ha='center', va='bottom', fontsize=16)
    if t != 0:
        plt.text(idx + bar_width/2, t, time_labels[idx], ha='center', va='bottom', fontsize=15)

plt.rcParams['axes.spines.top'] = False
plt.rcParams['axes.spines.right'] = False
plt.gcf().set_facecolor('none')

# Display the plot
plt.tight_layout()
plt.show()

# %%
for i, txt in enumerate(scdb_cluster_throughput):ax.set_yticklabels(['1', '2', '3', '4'], fontsize=20)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Updated data from the user's chart
categories = ['1K+', '5K+', '10K+']
scdb_cluster_throughput = [3.2, 3.1, 3.2]
scdb_single_throughput = [0.39, 0.40, 0.39]
eth_sc_throughput = [0.169, 0.168, 0.169]

# Provided color codes
color_scdb_cluster = '#ffd966'  # Yellow color for SCDB-cluster
color_scdb = '#ed7d31'          # Orange color for SCDB-single
color_eth_sc = '#5b9bd5'        # Blue color for ETH-SC

# Set up the figure and axis, adjusting the figure size to make the plot less spread out
fig, ax = plt.subplots(figsize=(7, 5))  # Smaller figure size

# Plot the lines with increased line width for boldness
ax.plot(categories, scdb_cluster_throughput, marker='o', color=color_scdb_cluster, linewidth=3, markersize=8, label='SCDB-cluster')
ax.plot(categories, scdb_single_throughput, marker='o', color=color_scdb, linewidth=3, markersize=8, label='SCDB-single')
ax.plot(categories, eth_sc_throughput, marker='o', color=color_eth_sc, linewidth=3, markersize=8, label='ETH-SC')

# Annotate the data points
for i, txt in enumerate(eth_sc_throughput):
    ax.annotate(f'{txt:.3f}', (categories[i], eth_sc_throughput[i]), textcoords="offset points", xytext=(0,10), ha='center', fontsize=14)
for i, txt in enumerate(scdb_single_throughput):
    ax.annotate(f'{txt:.2f}', (categories[i], scdb_single_throughput[i]), textcoords="offset points", xytext=(0,10), ha='center', fontsize=14)
for i, txt in enumerate(scdb_cluster_throughput):
    ax.annotate(f'{txt:.1f}', (categories[i], scdb_cluster_throughput[i]), textcoords="offset points", xytext=(0,10), ha='center', fontsize=14)

# Set the labels and title with a larger font size
ax.set_xlabel('# of transactions', fontsize=20)
ax.set_ylabel('Throughput [TPS]', fontsize=20)

# Set y-axis ticks to 1, 2, 3, 4
ax.set_yticks([1, 2, 3, 4])
ax.set_yticklabels(['1', '2', '3', '4'], fontsize=20)

# Increase the font size of the x-axis labels
ax.set_xticks(categories)
ax.set_xticklabels(categories, fontsize=20)

# Add a legend with a larger font size
ax.legend(fontsize=14)

# Show the plot without a title
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Updated data from the user's chart
categories = ['1K+', '5K+', '10K+']
scdb_single_throughput = [48, 51, 44]
scdb_cluster_throughput = [46, 47, 43]
eth_sc_throughput = [0.169, 0.168, 0.169]

transactions_int = [1000, 5000, 10000]

# Provided color codes # Yellow color for SCDB-cluster
color_scdb = '#ed7d31'          # Orange color for SCDB-single
color_eth_sc = '#5b9bd5'        # Blue color for ETH-SC

# Set up the figure and axis, adjusting the figure size to make the plot less spread out
# fig, ax = plt.subplots(figsize=(7, 5))  # Smaller figure size
fig, ax = plt.subplots()
# Plot the lines with increased line width for boldness
ax.plot(categories, scdb_cluster_throughput, marker='o', color=color_scdb_cluster, linewidth=3, markersize=8, label='SCDB-cluster')
ax.plot(categories, scdb_single_throughput, marker='o', color=color_scdb, linewidth=3, markersize=8, label='SCDB-single')
ax.plot(categories, eth_sc_throughput, marker='o', color=color_eth_sc, linewidth=3, markersize=8, label='ETH-SC')

# Annotate the data points
for i, txt in enumerate(eth_sc_throughput):
    ax.annotate(f'{txt:.3f}', (categories[i], eth_sc_throughput[i]), textcoords="offset points", xytext=(0,10), ha='center', fontsize=14)
for i, txt in enumerate(scdb_single_throughput):
    ax.annotate(f'{txt:.1f}', (categories[i], scdb_single_throughput[i]), textcoords="offset points", xytext=(0,10), ha='center', fontsize=14)
# for i, txt in enumerate(scdb_cluster_throughput):
#     ax.annotate(f'{txt:.1f}', (categories[i], scdb_cluster_throughput[i]), textcoords="offset points", xytext=(0,10), ha='center', fontsize=14)
for i, txt in enumerate(scdb_cluster_throughput):
    ax.annotate(f'{txt:.1f}', (categories[i], scdb_cluster_throughput[i]), textcoords="offset points", xytext=(0,-15), va='top', fontsize=14)


# Set the labels and title with a larger font size
ax.set_xlabel('# of transactions', fontsize=20)
ax.set_ylabel('Throughput [TPS]', fontsize=20)

# Set y-axis ticks to 1, 2, 3, 4
# ax.set_yticks([1, 2, 3, 4])
# ax.set_yticklabels(['1', '2', '3', '4'], fontsize=20)

# Increase the font size of the x-axis labels
ax.set_xticks(categories)
ax.set_xticklabels(categories, fontsize=20)

plt.yticks(fontsize=18)
plt.legend(fontsize=16)


# Add a legend with a larger font size
ax.legend(fontsize=14)
plt.rcParams['axes.spines.top'] = False
plt.rcParams['axes.spines.right'] = False
# Show the plot without a title
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming we have 4 data points for simplicity, you'll replace these with your actual data
capabilities = [1.09, 1.31, 1.49, 1.74]
eth_sc_create = [122.6, 217.014, 311.792, 398.432]
eth_sc_request = [140.5, 243.3, 339.5, 431.9]
scdb_create = [80.32, 79.41, 77.86, 80.79]
scdb_request = [245, 263.95, 251.55, 246.5]
color_scdb = '#ed7d31'          # Orange color for SCDB-single
color_eth_sc = '#5b9bd5'
# Create the plot
fig, ax = plt.subplots()

# Plotting the data
# ETH-SC CREATE
ax.plot(capabilities, eth_sc_create, marker='o', linestyle='-', color=color_eth_sc, linewidth=2,  markersize=8, label='ETH-SC CREATE')
# ETH-SC REQUEST
ax.plot(capabilities, eth_sc_request, marker='s', linestyle='--', color=color_eth_sc,linewidth=2,  markersize=8, label='ETH-SC REQUEST')
# SCDB CREATE
ax.plot(capabilities, scdb_create, marker='o', linestyle='-', color=color_scdb, linewidth=2, markersize=8, label='SCDB CREATE')
# SCDB REQUEST
ax.plot(capabilities, scdb_request, marker='s', linestyle='--', color=color_scdb,linewidth=2,  markersize=8, label='SCDB REQUEST')

# Increase the font size of the x-axis labels
ax.set_yscale('log')
ax.set_xlabel('Transaction size in KB', fontsize=18)
ax.set_ylabel('Latency in ms', fontsize=20)

# Set the font size of the tick labels
ax.set_xticks([1.09, 1.31, 1.49, 1.74])
ax.tick_params(axis='both', labelsize=17)

# Add a legend
ax.legend()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data points
capabilities = [1.09, 1.31, 1.49, 1.74]
eth_sc_accept = [1350, 1371, 1371, 1334]  # Example data, replace with actual values
scdb_accept = [377, 378, 378.1, 378.1]  # Example data, replace with actual values
eth_sc_bid = [2360, 10280, 28410, 67256]  # Example data, replace with actual values
scdb_bid = [100, 91, 93, 104]  # Example data, replace with actual values


# Colors for each line
color_eth_sc = '#5b9bd5'  # Blue color for ETH-SC
color_scdb = '#ed7d31'    # Orange color for SCDB

# Create the plot
fig, ax = plt.subplots()

# Plotting the data with markers, lines, and specific colors
# Use logarithmic scale for the y-axis
ax.set_yscale('log')

# Increase the linewidth for thicker lines and markersize for larger markers
ax.plot(capabilities, eth_sc_accept, marker='o', linestyle='-', color=color_eth_sc, linewidth=2, markersize=8, label='ETH-SC ACCEPT')
ax.plot(capabilities, scdb_accept, marker='o', linestyle='-', color=color_scdb, linewidth=2, markersize=8, label='SCDB ACCEPT')
ax.plot(capabilities, eth_sc_bid, marker='s', linestyle='--', color=color_eth_sc, linewidth=2, markersize=8, label='ETH-SC BID')
ax.plot(capabilities, scdb_bid, marker='s', linestyle='--', color=color_scdb, linewidth=2, markersize=8, label='SCDB BID')

# Annotate the last point for ETH-SC ACCEPT as it's the largest value
ax.annotate(f'{eth_sc_bid[-1]}', (capabilities[-1], eth_sc_bid[-1]), textcoords="offset points", xytext=(-34, -5), ha='center', fontsize=14)

# Set the labels and title with a larger font size
ax.set_xlabel('Transaction size in KB', fontsize=20)
ax.set_ylabel('Latency in ms', fontsize=20)

# Set the font size of the tick labels
ax.tick_params(axis='both', labelsize=17)
ax.set_xticks([1.09, 1.31, 1.49, 1.74])
# Add a legend
ax.legend()


# Adjust the layout to ensure there's no clipping of tick labels
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming we have 4 data points for simplicity, you'll replace these with your actual data
capabilities = [1.09, 1.31, 1.49, 1.74]
eth_sc_throughput = [0.77, 0.15, 0.06, 0.02]  # Example data
scdb_throughput = [46, 45, 44, 45]  # Example data

# Colors for each line
color_eth_sc = '#5b9bd5'  # Blue color for ETH-SC
color_scdb = '#ed7d31'    # Orange color for SCDB

# Create the plot
fig, ax = plt.subplots()

# Plotting the data with markers, lines, and specific colors
# Use logarithmic scale for the y-axis
ax.set_yscale('log')

# Increase the linewidth for thicker lines and markersize for larger markers
ax.plot(capabilities, eth_sc_throughput, marker='o', linestyle='-', color=color_eth_sc, linewidth=2, markersize=8, label='ETH-SC')
ax.plot(capabilities, scdb_throughput, marker='o', linestyle='-', color=color_scdb, linewidth=2, markersize=8, label='SCDB')

ax.annotate(f'{scdb_throughput[-1]:.2f}', (capabilities[-1], scdb_throughput[-1]), textcoords="offset points", xytext=(-10, -20), ha='center', fontsize=14)
ax.annotate(f'{eth_sc_throughput[-1]:.2f}', (capabilities[-1], eth_sc_throughput[-1]), textcoords="offset points", xytext=(-10, 15), ha='center', fontsize=14)

# Set the labels with a larger font size
ax.set_xlabel('Number of servers (validators)', fontsize=20)
ax.set_ylabel('Throughput [TPS]', fontsize=20)

# Set the font size of the tick labels
ax.tick_params(axis='both', labelsize=18)
ax.set_xticks([1.09, 1.31, 1.49, 1.74])

# Add a legend with a larger font size
ax.legend(fontsize=18)

# Adjust the layout to ensure there's no clipping of tick labels
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 5
#       3 # Assuming we have 4 data points for simplicity, you'll replace these with your actual data
#       4 capabilities = [1.09, 1.31, 1.49, 1.74]
# ----> 5 ax.set_xticks([1.09, 1.31, 1.49, 1.74])
#       6 eth_sc_throughput = [0.77, 0.15, 0.06, 0.02]  # Example data
#       7 scdb_throughput = [46, 45, 44, 45]  # Example data
#
# NameError: name 'ax' is not defined

# %%
import matplotlib.pyplot as plt

# Assuming we have 4 data points for simplicity, you'll replace these with your actual data
capabilities = [4, 8, 16, 32]
eth_sc_throughput = [0.77, 0.79, 0.80, 0.82]  # Example data
scdb_throughput = [43.5, 44.1, 44.7, 45.3]  # Example data

# Colors for each line
color_eth_sc = '#5b9bd5'  # Blue color for ETH-SC
color_scdb = '#ed7d31'    # Orange color for SCDB

# Create the plot
fig, ax = plt.subplots()

# Plotting the data with markers, lines, and specific colors
# Use logarithmic scale for the y-axis
ax.set_yscale('log')

# Increase the linewidth for thicker lines and markersize for larger markers
ax.plot(capabilities, eth_sc_throughput, marker='o', linestyle='-', color=color_eth_sc, linewidth=2, markersize=8, label='ETH-SC')
ax.plot(capabilities, scdb_throughput, marker='o', linestyle='-', color=color_scdb, linewidth=2, markersize=8, label='SCDB')

ax.annotate(f'{scdb_throughput[-1]:.2f}', (capabilities[-1], scdb_throughput[-1]), textcoords="offset points", xytext=(-10, -20), ha='center', fontsize=14)
ax.annotate(f'{eth_sc_throughput[-1]:.2f}', (capabilities[-1], eth_sc_throughput[-1]), textcoords="offset points", xytext=(-10, 15), ha='center', fontsize=14)

# Set the labels with a larger font size
ax.set_xlabel('Number of servers (validators)', fontsize=20)
ax.set_ylabel('Throughput [TPS]', fontsize=20)

# Set the font size of the tick labels
ax.tick_params(axis='both', labelsize=18)
ax.set_xticks([4, 8, 16, 32])

# Add a legend with a larger font size
ax.legend(fontsize=18)

# Adjust the layout to ensure there's no clipping of tick labels
plt.tight_layout()

# Show the plot
plt.show()

# %%
color_scdb = '#ed7d31'
color_eth_sc = '#5b9bd5'

# %%
import matplotlib.pyplot as plt

# Data points for SCDB

scdb_create = [122.6,128, 130, 135]
scdb_request = [141, 143, 144, 147]
scdb_accept = [1351, 1355, 1357, 1360]
scdb_bid = [2360, 2365, 2375, 2380]
num_servers = [4, 8, 16, 32]

# Colors for each metric
color_create = '#1f77b4'  # Blue
color_request = '#ff7f0e'  # Orange
color_accept = '#2ca02c'  # Green
color_bid = '#d62728'  # Red
color_throughput = '#9467bd'  # Purple  # Orange color for SCDB

# Create the plot
fig, ax = plt.subplots()

# Plotting the data with markers, lines, and specific colors
# Use logarithmic scale for the y-axis
ax.set_yscale('log')

# Increase the linewidth for thicker lines and markersize for larger markers
ax.plot(num_servers, scdb_create, marker='o', linestyle='-', color=color_create, linewidth=2, markersize=8, label='ETH-SC CREATE')
ax.plot(num_servers, scdb_request, marker='s', linestyle='--', color=color_create, linewidth=2, markersize=8, label='ETH-SC REQUEST')
ax.plot(num_servers, scdb_accept, marker='^', linestyle='-', color=color_create, linewidth=2, markersize=8, label='ETH-SC ACCEPT')
ax.plot(num_servers, scdb_bid, marker='d', linestyle='--', color=color_create, linewidth=2, markersize=8, label='ETH-SC BID')

# Set the labels with a larger font size
ax.set_xlabel('Number of servers (validators)', fontsize=20)
ax.set_ylabel('Latency in ms', fontsize=20)

# Set the font size of the tick labels
ax.tick_params(axis='both', labelsize=18)
ax.set_xticks(num_servers)

# Add a legend with a larger font size
ax.legend(fontsize=14)

# Adjust the layout to ensure there's no clipping of tick labels
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data points for SCDB

scdb_create = [83.32, 85.41, 88.86, 89.79]
scdb_request = [258, 263.95, 271.55, 280.5]
scdb_accept = [380, 385, 395, 410]
scdb_bid = [100, 103, 105, 106]
num_servers = [4, 8, 16, 32]

# Colors for each metric
color_create = '#1f77b4'  # Blue
color_request = '#ff7f0e'  # Orange
color_accept = '#2ca02c'  # Green
color_bid = '#d62728'  # Red
color_throughput = '#9467bd'  # Purple  # Orange color for SCDB

# Create the plot
fig, ax = plt.subplots()

# Plotting the data with markers, lines, and specific colors
# Use logarithmic scale for the y-axis
ax.set_yscale('log')

# Increase the linewidth for thicker lines and markersize for larger markers
ax.plot(num_servers, scdb_create, marker='o', linestyle='-', color=color_request, linewidth=2, markersize=8, label='SCDB CREATE')
ax.plot(num_servers, scdb_request, marker='s', linestyle='--', color=color_request, linewidth=2, markersize=8, label='SCDB REQUEST')
ax.plot(num_servers, scdb_accept, marker='^', linestyle='-', color=color_request, linewidth=2, markersize=8, label='SCDB ACCEPT')
ax.plot(num_servers, scdb_bid, marker='d', linestyle='--', color=color_request, linewidth=2, markersize=8, label='SCDB BID')

# Set the labels with a larger font size
ax.set_xlabel('Number of servers (validators)', fontsize=20)
ax.set_ylabel('Latency in ms', fontsize=20)

# Set the font size of the tick labels
ax.tick_params(axis='both', labelsize=18)
ax.set_xticks(num_servers)

# Add a legend with a larger font size
ax.legend(fontsize=14)

# Adjust the layout to ensure there's no clipping of tick labels
plt.tight_layout()

# Show the plot
plt.show()
